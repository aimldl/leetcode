# %% [markdown]
# # [02 Skills > Easy > 1929. Concatenation of Array](https://leetcode.com/problems/concatenation-of-array/description/?envType=problem-list-v2&envId=d5titt6h)

# %% [markdown]
# Given an integer array nums of length n, you want to create an array ans of length 2n where ans[i] == nums[i] and ans[i + n] == nums[i] for 0 <= i < n (0-indexed).
#
# Specifically, ans is the concatenation of two nums arrays.
#
# Return the array ans.
#
#
#
# Example 1:
# ```
# Input: nums = [1,2,1]
# Output: [1,2,1,1,2,1]
# ```
# Explanation: The array ans is formed as follows:
# - ans = [nums[0],nums[1],nums[2],nums[0],nums[1],nums[2]]
# - ans = [1,2,1,1,2,1]
#
#
# Example 2:
# ```
# Input: nums = [1,3,2,1]
# Output: [1,3,2,1,1,3,2,1]
# ```
# Explanation: The array ans is formed as follows:
# - ans = [nums[0],nums[1],nums[2],nums[3],nums[0],nums[1],nums[2],nums[3]]
# - ans = [1,3,2,1,1,3,2,1]
#
# Constraints:
# ```
# n == nums.length
# 1 <= n <= 1000
# 1 <= nums[i] <= 1000
# ```

# %% [markdown]
# ## Code
# ```Python3
# class Solution:
#     def getConcatenation(self, nums: List[int]) -> List[int]:
#
# ```

# %% [markdown]
# ## Practice

# %%
nums = [1,2,1]

# %%
length = len(nums)

# %% [markdown]
# Given an integer array nums of length n, you want to create an array ans of length 2n where ans[i] == nums[i] and ans[i + n] == nums[i] for 0 <= i < n (0-indexed).

# %%
ans = nums

# %%
def getConcatenation(nums):
    length = len(nums)

    ans = nums
    for i in range(length):
        ans.append(nums[i])
    return ans

# %%
getConcatenation(nums)
# Out:
# [1, 2, 1, 1, 2, 1]

# %% [markdown]
# ## Submission

# %%
class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:
        length = len(nums)

        ans = nums
        for i in range(length):
            ans.append(nums[i])

        return ans

# %% [markdown]
# ## Making it even more Pythonic
# ### Option 1. Use +

# %%
class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:
        return nums + nums

# %% [markdown]
# ### Option 2. Use *

# %%
class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:
        return nums * 2
