# %% [markdown]
# <a href="https://colab.research.google.com/github/aimldl/leetcode/blob/main/04-1480_Running_Sum_of_1d_Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04-1480. Running Sum of 1d Array
